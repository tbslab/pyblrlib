# %%
import blrlib as bl
import numpy as np

A = np.random.randint(1, 10, (50, 50))
nb = 5
indices = [(i, i) for i in range(nb)]

# %%
X = bl.generate_blrmatrix(A, nb, indices, rank=1)
print(X)
# Out:
# blrmatrix(5x5)
# (0, 0): matrix(10x10)
# (0, 1): lrmatrix(10x10, 1)
# (0, 2): lrmatrix(10x10, 1)
# (0, 3): lrmatrix(10x10, 1)
# (0, 4): lrmatrix(10x10, 1)
# (1, 0): lrmatrix(10x10, 1)
# (1, 1): matrix(10x10)
# (1, 2): lrmatrix(10x10, 1)
# (1, 3): lrmatrix(10x10, 1)
# (1, 4): lrmatrix(10x10, 1)
# (2, 0): lrmatrix(10x10, 1)
# (2, 1): lrmatrix(10x10, 1)
# (2, 2): matrix(10x10)
# (2, 3): lrmatrix(10x10, 1)
# (2, 4): lrmatrix(10x10, 1)
# (3, 0): lrmatrix(10x10, 1)
# (3, 1): lrmatrix(10x10, 1)
# (3, 2): lrmatrix(10x10, 1)
# (3, 3): matrix(10x10)
# (3, 4): lrmatrix(10x10, 1)
# (4, 0): lrmatrix(10x10, 1)
# (4, 1): lrmatrix(10x10, 1)
# (4, 2): lrmatrix(10x10, 1)
# (4, 3): lrmatrix(10x10, 1)
# (4, 4): matrix(10x10)
